# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanbagawan/23CS520/blob/main/see.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

df = ps.read_csv("/content/Mall_Customers (2).csv")
df.head()

# %%
df = ps.read_csv("/content/Mall_Customers (2).csv")
df.head()
x = df.iloc[:, [2, 3, 4]].values
wcss=[]
for i in range(1,11):
  kmeans =KMeans(n_clusters=i,init='k-means++',random_state=42, n_init='auto')
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.show()

# %%
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1], c='red', marker='0')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.title('Clusters of Customers')
plt.show()
